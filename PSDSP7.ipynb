# %%
##Operator aritmatika
print('penjumlahan')
print(3+16)
print('pengurangan')
print(6-3)
print('perkalian')
print(3*6)
print('pembagian')
print(3/6)
print('modulus')
print(16%3)
print('perpangkatan')
print(3**6)
print('pembagian pembulatan flooring')
print(16//3)
# Out:
# penjumlahan
# 19
# pengurangan
# 3
# perkalian
# 18
# pembagian
# 0.5
# modulus
# 1
# perpangkatan
# 729
# pembagian pembulatan flooring
# 5

# %%
##Operator assignment
print('penjumlahan')
x=3
x=x+6
print(x)
print('pengurangan')
x=3
x=x-16
print(x)
print('perkalian')
x=3
x=x*6
print(x)
print('pembagian')
x=16
x=x/3
print(x)
print('modulus')
x=3
x=x%16
print(x)
print('pembagian flooring')
x=16
x=x//3
print(x)
print('perpangkatan')
x=3
x=x**3
print(x)
# Out:
# penjumlahan
# 9
# pengurangan
# -13
# perkalian
# 18
# pembagian
# 5.333333333333333
# modulus
# 3
# pembagian flooring
# 5
# perpangkatan
# 27

# %%
##Operator pembanding
print(3==3)
print(6!=6)
print(3>6)
print(3<6)
print(3>=3)
print(6<=6)
# Out:
# True
# False
# False
# True
# True
# True

# %%
##Operator logika
print(True and False)
print(False or False)
print(not False and True)
# Out:
# False
# False
# True

# %%
##Operator keanggotaan
d=(3,5,6,16,24)
c=3
print(c in d)
r=(3,5,6,16,24)
d=1
print(d not in r)
# Out:
# True
# True

# %%
##Variabel
kalimat='abang tukang bakso'
bil1=3
bil2=3.16
bil3=True
bil4=3j+6
print(kalimat)
print(bil1)
print(bil2)
print(bil3)
print(bil4)
# Out:
# abang tukang bakso
# 3
# 3.16
# True
# (6+3j)

# %%
##Tipe data
print(type(kalimat))
print(type(bil1))
print(type(bil2))
print(type(bil3))
print(type(bil4))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

# %%
##Konversi tipe data
print(int(bil2))
print(int(bil3))
print(float(bil1))
print(float(bil3))
print(str(bil3))
print(str(bil4))
print(bool(bil2))
print(bool(bil4))
print(complex(bil1))
print(complex(bil3))
# Out:
# 3
# 1
# 3.0
# 1.0
# True
# (6+3j)
# True
# True
# (3+0j)
# (1+0j)
